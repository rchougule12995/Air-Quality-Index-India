# %% [markdown]
# <a href="https://colab.research.google.com/github/rchougule12995/Air-Quality-Index-India/blob/master/templates/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"Performance Test"
# Out:
# 'Performance Test'

# %%
"Google"
# Out:
# 'Google'

# %%
"SEM"
# Out:
# 'SEM'
